# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import japanize_matplotlib
import seaborn as sns
from sklearn.model_selection import KFold, cross_val_score, train_test_split, cross_val_predict

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Bidirectional, Dropout
from tensorflow.keras.optimizers import Adam
from keras.regularizers import l2
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import DBSCAN
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from math import sqrt

from scipy.stats import randint
from scipy.special import boxcox
from scipy.special import inv_boxcox

pd.set_option('display.max_columns', None)
# Out:
# D:\Anaconda\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model_type = 1

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    tf.config.experimental.set_memomry_growth(gpus[0],True)
    tf.config.set_visible_devices([gpus[0]],'GPU')

# %%
def calculate_alpha_beta(mean,var):
    return var/mean , mean/(var/mean)

# %%
def pearson_corr_2(x, y):
    x_diff = x - np.mean(x)
    y_diff = y - np.mean(y)
    r2_c = (np.dot(x_diff, y_diff) / (np.sqrt(sum(x_diff ** 2)) * np.sqrt(sum(y_diff ** 2)))) ** 2
    return r2_c

# %%
def check_deviation(group):
    values = group['Est_AC_POWER'].values
    for i in range(len(values)):
        for j in range(i + 1, len(values)):
            if abs(values[i] - values[j]) / max(values[i], values[j]) > 0.5:
                return True
    return False

# %%
def create_LSTM(model_type,input_shape):
    
    if model_type == 1:
        model = Sequential()
        model.add(LSTM(50, activation='tanh', input_shape=input_shape, kernel_regularizer=l2(0.01)))
        model.add(Dropout(0.2))
        model.add(Dense(1,kernel_regularizer=l2(0.01)))

    if model_type == 2:
        model = Sequential()
        model.add(LSTM(50, activation='tanh', return_sequences=True, input_shape=input_shape, kernel_regularizer=l2(0.01)))
        model.add(Dropout(0.2))
        model.add(LSTM(50, activation='tanh',kernel_regularizer=l2(0.01)))
        model.add(Dropout(0.2))
        model.add(Dense(1,kernel_regularizer=l2(0.01)))

    if model_type == 3:
        model = Sequential()
        model.add(Bidirectional(LSTM(50, activation='tanh', input_shape=input_shape, kernel_regularizer=l2(0.01))))
        model.add(Dropout(0.2))
        model.add(Dense(1,kernel_regularizer=l2(0.01)))
        
    model.compile(optimizer=Adam(learning_rate=0.3), loss='mean_squared_error')
    
    return model

# %%
# dataset = pd.read_csv('dataset.csv')
dataset = pd.read_csv('cleand_dataset.csv')
dataset.tail()
# Out:
#        Unnamed: 0.1  Unnamed: 0  TRIP_ID  SUB_ID  SEGMENT_ID  \
# 15347         17464       17464     4560       1          22
# 15348         17465       17465     4560       1          23
# 15349         17466       17466     4560       1          24
# 15350         17467       17467     4560       1          25
# 15351         17468       17468     4560       1          26
#
#                 START_TIME             END_TIME  START_LATITUDE  \
# 15347  2023-08-30 10:50:00  2023-08-30 10:50:00       35.449129
# 15348  2023-08-30 10:50:00  2023-08-30 11:00:00       35.452996
# 15349  2023-08-30 11:00:00  2023-08-30 11:00:00       35.459174
# 15350  2023-08-30 11:00:00  2023-08-30 11:00:00       35.466307
# 15351  2023-08-30 11:00:00  2023-08-30 11:00:00       35.472929
#
#        START_LONGITUDE  LAST_LATITUDE  LAST_LONGITUDE  START_ALTITUDE  \
# 15347       139.567853      35.452739      139.576851            57.7
# 15348       139.577632      35.458544      139.585216            60.5
# 15349       139.585967      35.465691      139.591233            32.4
# 15350       139.591511      35.472796      139.595000            25.8
# 15351       139.594838      35.472286      139.586766            49.3
#
#        LAST_ALTITUDE  AVG_ALTITUDE  START_SOC  END_SOC  START_GIDS  END_GIDS  \
# 15347           64.2     59.858333     728318   726240         522       521
# 15348           34.8     46.375000     726224   726472         521       521
# 15349           24.4     24.725000     726530   725422         521       520
# 15350           49.0     42.200000     725100   722048         520       518
# 15351           50.9     48.887097     721812   718416         518       515
#
#          SOH  AVG_SPEED  RUN_TIME  TRIP_TIME  DROP_TIME  BETTERY_TEMPERATURA  \
# 15347  91.97  70.764000    3817.0       51.0        0.0            32.358333
# 15348  91.97  70.881001    3868.0       51.0        0.0            32.366667
# 15349  91.97  69.768000    3918.0       50.0        0.0            32.386111
# 15350  91.97  27.947172    4047.0      129.0        0.0            32.440230
# 15351  91.97  15.419032    4310.0      263.0        0.0            32.493011
#
#        AMBIENT_TEMPERATURA     EV_POWER    RUN_POWER   AUX_POWER    AC_POWER  \
# 15347            32.833333  8988.018412  8038.018412  200.000000  750.000000
# 15348            33.000000 -1109.831677 -2059.831677  200.000000  750.000000
# 15349            33.291667  4570.528872  3620.528872  200.000000  750.000000
# 15350            33.500000  4200.582567  3250.582567  200.000000  750.000000
# 15351            33.233871  2664.847759  1729.363888  217.741935  717.741935
#
#        Est_AC_POWER  ALL_Consumption_Wh  RUN_Consumption_Wh  \
# 15347    666.666667          123.898511          110.440178
# 15348    716.666667          -15.617443          -29.075777
# 15349    720.833333           62.262229           49.067784
# 15350    743.103448          132.393101           98.351435
# 15351    740.322581          192.796632          124.282743
#
#        AUX_Consumption_Wh  AC_Consumption_Wh  EST_AC_Consumption_Wh  \
# 15347            2.833333          10.625000               9.444444
# 15348            2.833333          10.625000              10.166667
# 15349            2.777778          10.416667              10.000000
# 15350            7.166667          26.875000              26.527778
# 15351           15.944444          52.569444              54.180556
#
#        TEMPERATURE_yokohama  TEMPERATURE_ebina   HUMIDITY  \
# 15347                  31.9          31.799999  20.857681
# 15348                  31.9          31.974999  21.109992
# 15349                  31.9          32.500000  21.866924
# 15350                  31.9          32.500000  21.866924
# 15351                  31.9          32.500000  21.866924
#
#        WIND_SPEED_yokohama  WIND_SPEED_ebina   ILLUMINANCE  \
# 15347                 5.20               3.5  38488.187489
# 15348                 5.15               3.4  37195.114358
# 15349                 5.00               3.1  33315.894966
# 15350                 5.00               3.1  33315.894966
# 15351                 5.00               3.1  33315.894966
#
#        PRECIPITATION_START_yokohama  PRECIPITATION_END_yokohama  \
# 15347                           0.0                         0.0
# 15348                           0.0                         0.0
# 15349                           0.0                         0.0
# 15350                           0.0                         0.0
# 15351                           0.0                         0.0
#
#        PRECIPITATION_START_ebina  PRECIPITATION_END_ebina WEATHER  \
# 15347                        0.0                      0.0    晴のち曇
# 15348                        0.0                      0.0    晴のち曇
# 15349                        0.0                      0.0    晴のち曇
# 15350                        0.0                      0.0    晴のち曇
# 15351                        0.0                      0.0    晴のち曇
#
#        ILLUMINANCE_Log  TRIP_TEMPERATURE  AVG_TEMPERATURE  \
# 15347                4         32.000791        31.849999
# 15348                4         32.000791        31.937500
# 15349                4         32.000791        32.200000
# 15350                4         32.000791        32.200000
# 15351                4         32.000791        32.200000
#
#        AVG_PRECIPITATION_START  AVG_PRECIPITATION_END
# 15347                      0.0                    0.0
# 15348                      0.0                    0.0
# 15349                      0.0                    0.0
# 15350                      0.0                    0.0
# 15351                      0.0                    0.0

# %%
features = ['RUN_TIME','DROP_TIME','AVG_SPEED','AVG_ALTITUDE','AVG_TEMPERATURE','HUMIDITY','ILLUMINANCE_Log','AVG_PRECIPITATION_START','AVG_PRECIPITATION_END']
poly = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)
sc = MinMaxScaler(feature_range=(0,1))

dataset_groupby = dataset.groupby(['TRIP_ID']).sum(numeric_only=True)
id_list = dataset_groupby[(dataset_groupby['EST_AC_Consumption_Wh']>50)].index.tolist()
dataset = dataset[dataset['TRIP_ID'].isin(id_list)]

# %%
dataset.reset_index(inplace=True)
kfold_groups = dataset['TRIP_ID'].unique()
kf = KFold(n_splits=10, shuffle=True, random_state=50)

result_real = []
result_pred = []

for train_index, test_index in kf.split(kfold_groups):

    train = dataset[dataset['TRIP_ID'].isin(kfold_groups[train_index])]
    test = dataset[dataset['TRIP_ID'].isin(kfold_groups[test_index])]
    
    X_train = poly.fit_transform(sc.fit_transform(train[features]))
    X_test = poly.fit_transform(sc.transform(test[features]))
    
    Y_train = train['Est_AC_POWER']
    Y_test = test['Est_AC_POWER']
    
    Y_train = boxcox(train['Est_AC_POWER'], 0.24)
    Y_test = boxcox(test['Est_AC_POWER'], 0.24)
    
    LSTM_model = create_LSTM(1,(X_train.shape[1], 1))
    LSTM_model.fit(X_train, Y_train, epochs=30, batch_size=32, validation_data=(X_test, Y_test), verbose=1)

    Y_pred = LSTM_model.predict(X_test)
    
#     result_real.append(list(Y_test))
#     result_pred.append(list(Y_pred))
#     dataset.loc[test.index, 'Pred_AC_POWER'] = list(Y_pred)
    
    result_real.append(list(inv_boxcox(Y_test, 0.24)))
    result_pred.append(list(inv_boxcox(Y_pred, 0.24)))
    dataset.loc[test.index, 'Pred_AC_POWER'] = list(inv_boxcox(Y_pred, 0.24))
# Out:
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/30
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 399/399 [==============================] - 6s 11ms/step - loss: 18.2005 - val_loss: 20.5186
# Epoch 2/30
# 399/399 [==============================] - 4s 10ms/step - loss: 17.0214 - val_loss: 25.0541
# Epoch 3/30
# 399/399 [==============================] - 6s 15ms/step - loss: 16.8582 - val_loss: 27.5353
# Epoch 4/30
# 399/399 [==============================] - 12s 31ms/step - loss: 17.0554 - val_loss: 23.5959
# Epoch 5/30
# 399/399 [==============================] - 14s 34ms/step - loss: 17.0037 - val_loss: 20.6649
# Epoch 6/30
# 399/399 [==============================] - 7s 18ms/step - loss: 17.1836 - val_loss: 20.4809
# Epoch 7/30
# 399/399 [==============================] - 6s 14ms/step - loss: 16.9895 - val_loss: 23.6121
# Epoch 8/30
# 399/399 [==============================] - 4s 9ms/step - loss: 17.3699 - val_loss: 21.0261
# Epoch 9/30
# 399/399 [==============================] - 4s 9ms/step - loss: 16.6510 - val_loss: 20.4735
# Epoch 10/30
# 399/399 [==============================] - 4s 9ms/step - loss: 16.7127 - val_loss: 23.7360
# Epoch 11/30
# 399/399 [==============================] - 7s 17ms/step - loss: 17.0125 - val_loss: 20.6908
# Epoch 12/30
# 399/399 [==============================] - 6s 16ms/step - loss: 16.8561 - val_loss: 20.4796
# Epoch 13/30
# 399/399 [==============================] - 5s 12ms/step - loss: 17.0714 - val_loss: 20.7469
# Epoch 14/30
# 399/399 [==============================] - 4s 10ms/step - loss: 16.8658 - val_loss: 21.0599
# Epoch 15/30
# 399/399 [==============================] - 4s 10ms/step - loss: 17.1195 - val_loss: 24.2756
# Epoch 16/30
# 399/399 [==============================] - 4s 10ms/step - loss: 16.8067 - val_loss: 20.4827
# Epoch 17/30
# 399/399 [==============================] - 4s 9ms/step - loss: 16.7539 - val_loss: 21.7840
# Epoch 18/30
# 399/399 [==============================] - 4s 10ms/step - loss: 17.1745 - val_loss: 24.3984
# Epoch 19/30
# 399/399 [==============================] - 4s 10ms/step - loss: 16.9432 - val_loss: 20.5000
# Epoch 20/30
# 399/399 [==============================] - 4s 9ms/step - loss: 16.9753 - val_loss: 21.3301
# Epoch 21/30
# 399/399 [==============================] - 4s 9ms/step - loss: 17.1263 - val_loss: 21.3734
# Epoch 22/30
# 399/399 [==============================] - 4s 9ms/step - loss: 16.7081 - val_loss: 23.9520
# Epoch 23/30
# 399/399 [==============================] - 4s 9ms/step - loss: 17.0531 - val_loss: 24.1688
# Epoch 24/30
# 399/399 [==============================] - 4s 9ms/step - loss: 16.6640 - val_loss: 20.4915
# Epoch 25/30
# 399/399 [==============================] - 4s 9ms/step - loss: 16.9094 - val_loss: 20.4798
# Epoch 26/30
# 399/399 [==============================] - 4s 9ms/step - loss: 17.1991 - val_loss: 20.6296
# Epoch 27/30
# 399/399 [==============================] - 4s 9ms/step - loss: 17.4764 - val_loss: 22.4133
# Epoch 28/30
# 399/399 [==============================] - 4s 9ms/step - loss: 16.5742 - val_loss: 21.7003
# Epoch 29/30
# 399/399 [==============================] - 4s 9ms/step - loss: 17.1208 - val_loss: 20.6123
# Epoch 30/30
# 399/399 [==============================] - 4s 9ms/step - loss: 17.1287 - val_loss: 21.7645
# 45/45 [==============================] - 0s 4ms/step
# Epoch 1/30
# 401/401 [==============================] - 5s 10ms/step - loss: 19.0242 - val_loss: 17.3488
# Epoch 2/30
# 401/401 [==============================] - 4s 9ms/step - loss: 17.7553 - val_loss: 17.0367
# Epoch 3/30
# 401/401 [==============================] - 4s 9ms/step - loss: 17.4723 - val_loss: 17.4463
# Epoch 4/30
# 401/401 [==============================] - 4s 9ms/step - loss: 17.4610 - val_loss: 16.8532
# Epoch 5/30
# 401/401 [==============================] - 4s 9ms/step - loss: 18.0573 - val_loss: 42.8990
# Epoch 6/30
# 401/401 [==============================] - 4s 10ms/step - loss: 17.7891 - val_loss: 16.8833
# Epoch 7/30
# 401/401 [==============================] - 4s 10ms/step - loss: 17.7504 - val_loss: 18.0052
# Epoch 8/30
# 401/401 [==============================] - 4s 9ms/step - loss: 18.0102 - val_loss: 16.9094
# Epoch 9/30
# 401/401 [==============================] - 4s 9ms/step - loss: 17.6910 - val_loss: 16.8277
# Epoch 10/30
# 401/401 [==============================] - 4s 10ms/step - loss: 17.7345 - val_loss: 16.8277
# Epoch 11/30
# 401/401 [==============================] - 4s 9ms/step - loss: 17.6207 - val_loss: 17.2675
# Epoch 12/30
# 401/401 [==============================] - 4s 10ms/step - loss: 17.4013 - val_loss: 21.3913
# Epoch 13/30
# 401/401 [==============================] - 4s 10ms/step - loss: 18.3083 - val_loss: 25.0531
# Epoch 14/30
# 401/401 [==============================] - 4s 10ms/step - loss: 17.5729 - val_loss: 16.9014
# Epoch 15/30
# 401/401 [==============================] - 4s 10ms/step - loss: 17.9885 - val_loss: 17.6403
# Epoch 16/30
# 401/401 [==============================] - 4s 9ms/step - loss: 17.7085 - val_loss: 21.8685
# Epoch 17/30
# 401/401 [==============================] - 4s 10ms/step - loss: 18.0909 - val_loss: 17.1100
# Epoch 18/30
# 401/401 [==============================] - 4s 10ms/step - loss: 17.4472 - val_loss: 18.4069
# Epoch 19/30
# 401/401 [==============================] - 4s 9ms/step - loss: 17.3998 - val_loss: 18.2024
# Epoch 20/30
# 401/401 [==============================] - 4s 10ms/step - loss: 17.7693 - val_loss: 23.6658
# Epoch 21/30
# 401/401 [==============================] - 4s 9ms/step - loss: 17.5682 - val_loss: 16.8429
# Epoch 22/30
# 401/401 [==============================] - 4s 9ms/step - loss: 18.2800 - val_loss: 25.6476
# Epoch 23/30
# 401/401 [==============================] - 4s 10ms/step - loss: 17.2306 - val_loss: 24.8122
# Epoch 24/30
# 401/401 [==============================] - 4s 9ms/step - loss: 17.3749 - val_loss: 16.7992
# Epoch 25/30
# 401/401 [==============================] - 4s 9ms/step - loss: 17.6906 - val_loss: 18.6515
# Epoch 26/30
# 401/401 [==============================] - 4s 9ms/step - loss: 18.2161 - val_loss: 16.8604
# Epoch 27/30
# 401/401 [==============================] - 4s 9ms/step - loss: 17.7073 - val_loss: 25.2789
# Epoch 28/30
# 401/401 [==============================] - 4s 9ms/step - loss: 17.6332 - val_loss: 17.0700
# Epoch 29/30
# 401/401 [==============================] - 4s 9ms/step - loss: 17.9798 - val_loss: 16.9735
# Epoch 30/30
# 401/401 [==============================] - 4s 9ms/step - loss: 17.7061 - val_loss: 17.0117
# 43/43 [==============================] - 0s 4ms/step
# Epoch 1/30
# 400/400 [==============================] - 5s 10ms/step - loss: 18.9792 - val_loss: 13.4629
# Epoch 2/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.6135 - val_loss: 13.3984
# Epoch 3/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.8502 - val_loss: 13.5606
# Epoch 4/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.5637 - val_loss: 13.4790
# Epoch 5/30
# 400/400 [==============================] - 4s 9ms/step - loss: 18.0522 - val_loss: 13.4071
# Epoch 6/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.5426 - val_loss: 13.6437
# Epoch 7/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.6871 - val_loss: 13.4614
# Epoch 8/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.7701 - val_loss: 15.5733
# Epoch 9/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.6758 - val_loss: 13.5052
# Epoch 10/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.6509 - val_loss: 16.5522
# Epoch 11/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.5330 - val_loss: 14.2979
# Epoch 12/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.5008 - val_loss: 13.4129
# Epoch 13/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.4680 - val_loss: 14.6042
# Epoch 14/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.3327 - val_loss: 13.4541
# Epoch 15/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.5730 - val_loss: 21.0448
# Epoch 16/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.8641 - val_loss: 13.5739
# Epoch 17/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.4127 - val_loss: 13.7841
# Epoch 18/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.7432 - val_loss: 15.8527
# Epoch 19/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.9682 - val_loss: 17.0854
# Epoch 20/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.5287 - val_loss: 13.5852
# Epoch 21/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.6356 - val_loss: 13.3983
# Epoch 22/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.6594 - val_loss: 13.5113
# Epoch 23/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.9265 - val_loss: 14.5104
# Epoch 24/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.4737 - val_loss: 18.8756
# Epoch 25/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.6472 - val_loss: 17.1698
# Epoch 26/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.7044 - val_loss: 13.7542
# Epoch 27/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.7251 - val_loss: 14.5496
# Epoch 28/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.4914 - val_loss: 14.8474
# Epoch 29/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.8507 - val_loss: 13.8416
# Epoch 30/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.5117 - val_loss: 13.5873
# 44/44 [==============================] - 0s 4ms/step
# Epoch 1/30
# 398/398 [==============================] - 5s 10ms/step - loss: 18.4975 - val_loss: 15.9218
# Epoch 2/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.6325 - val_loss: 22.4017
# Epoch 3/30
# 398/398 [==============================] - 4s 9ms/step - loss: 17.4322 - val_loss: 17.2349
# Epoch 4/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.5370 - val_loss: 17.5193
# Epoch 5/30
# 398/398 [==============================] - 4s 9ms/step - loss: 17.2934 - val_loss: 19.3055
# Epoch 6/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.4930 - val_loss: 15.9073
# Epoch 7/30
# 398/398 [==============================] - 4s 10ms/step - loss: 18.0683 - val_loss: 15.8961
# Epoch 8/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.4566 - val_loss: 17.6770
# Epoch 9/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.3306 - val_loss: 17.5389
# Epoch 10/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.5289 - val_loss: 16.2241
# Epoch 11/30
# 398/398 [==============================] - 4s 9ms/step - loss: 17.1265 - val_loss: 16.0169
# Epoch 12/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.4623 - val_loss: 16.6676
# Epoch 13/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.7509 - val_loss: 18.1077
# Epoch 14/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.6394 - val_loss: 15.9361
# Epoch 15/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.7399 - val_loss: 15.9909
# Epoch 16/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.3032 - val_loss: 16.5819
# Epoch 17/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.3606 - val_loss: 16.7210
# Epoch 18/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.5823 - val_loss: 16.0314
# Epoch 19/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.2171 - val_loss: 16.6316
# Epoch 20/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.4838 - val_loss: 15.8877
# Epoch 21/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.5423 - val_loss: 17.6071
# Epoch 22/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.9223 - val_loss: 15.9081
# Epoch 23/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.4532 - val_loss: 23.2762
# Epoch 24/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.8382 - val_loss: 15.9109
# Epoch 25/30
# 398/398 [==============================] - 4s 9ms/step - loss: 17.3273 - val_loss: 15.9937
# Epoch 26/30
# 398/398 [==============================] - 4s 9ms/step - loss: 17.0932 - val_loss: 15.9421
# Epoch 27/30
# 398/398 [==============================] - 4s 9ms/step - loss: 17.8971 - val_loss: 20.6001
# Epoch 28/30
# 398/398 [==============================] - 4s 9ms/step - loss: 17.5411 - val_loss: 17.0262
# Epoch 29/30
# 398/398 [==============================] - 4s 9ms/step - loss: 17.4633 - val_loss: 20.5070
# Epoch 30/30
# 398/398 [==============================] - 4s 9ms/step - loss: 17.8134 - val_loss: 17.7444
# 46/46 [==============================] - 0s 4ms/step
# Epoch 1/30
# 399/399 [==============================] - 5s 10ms/step - loss: 19.9388 - val_loss: 12.8114
# Epoch 2/30
# 399/399 [==============================] - 4s 9ms/step - loss: 18.0114 - val_loss: 13.5444
# Epoch 3/30
# 399/399 [==============================] - 4s 9ms/step - loss: 18.2738 - val_loss: 14.6207
# Epoch 4/30
# 399/399 [==============================] - 4s 9ms/step - loss: 18.3565 - val_loss: 12.7229
# Epoch 5/30
# 399/399 [==============================] - 4s 9ms/step - loss: 18.2997 - val_loss: 25.6711
# Epoch 6/30
# 399/399 [==============================] - 4s 9ms/step - loss: 17.9692 - val_loss: 12.8215
# Epoch 7/30
# 399/399 [==============================] - 4s 9ms/step - loss: 18.0234 - val_loss: 12.7876
# Epoch 8/30
# 399/399 [==============================] - 4s 9ms/step - loss: 18.5042 - val_loss: 15.0380
# Epoch 9/30
# 399/399 [==============================] - 4s 10ms/step - loss: 17.8048 - val_loss: 12.7248
# Epoch 10/30
# 399/399 [==============================] - 4s 9ms/step - loss: 18.0462 - val_loss: 12.7308
# Epoch 11/30
# 399/399 [==============================] - 4s 9ms/step - loss: 17.9532 - val_loss: 13.7900
# Epoch 12/30
# 399/399 [==============================] - 4s 9ms/step - loss: 18.4734 - val_loss: 15.9153
# Epoch 13/30
# 399/399 [==============================] - 4s 9ms/step - loss: 18.2834 - val_loss: 15.0493
# Epoch 14/30
# 399/399 [==============================] - 4s 9ms/step - loss: 18.2815 - val_loss: 13.1651
# Epoch 15/30
# 399/399 [==============================] - 4s 9ms/step - loss: 18.5443 - val_loss: 13.1397
# Epoch 16/30
# 399/399 [==============================] - 4s 9ms/step - loss: 18.0555 - val_loss: 13.3541
# Epoch 17/30
# 399/399 [==============================] - 4s 9ms/step - loss: 17.8062 - val_loss: 20.1495
# Epoch 18/30
# 399/399 [==============================] - 4s 10ms/step - loss: 18.1433 - val_loss: 13.0023
# Epoch 19/30
# 399/399 [==============================] - 4s 9ms/step - loss: 19.7295 - val_loss: 12.7577
# Epoch 20/30
# 399/399 [==============================] - 4s 9ms/step - loss: 18.3984 - val_loss: 14.2861
# Epoch 21/30
# 399/399 [==============================] - 4s 10ms/step - loss: 18.2641 - val_loss: 13.8456
# Epoch 22/30
# 399/399 [==============================] - 4s 9ms/step - loss: 17.7047 - val_loss: 12.7807
# Epoch 23/30
# 399/399 [==============================] - 4s 10ms/step - loss: 18.2570 - val_loss: 12.7558
# Epoch 24/30
# 399/399 [==============================] - 4s 10ms/step - loss: 17.7454 - val_loss: 16.0636
# Epoch 25/30
# 399/399 [==============================] - 4s 10ms/step - loss: 18.7301 - val_loss: 13.0412
# Epoch 26/30
# 399/399 [==============================] - 4s 10ms/step - loss: 18.1869 - val_loss: 12.7470
# Epoch 27/30
# 399/399 [==============================] - 4s 10ms/step - loss: 18.0949 - val_loss: 13.5817
# Epoch 28/30
# 399/399 [==============================] - 4s 9ms/step - loss: 18.3249 - val_loss: 12.7656
# Epoch 29/30
# 399/399 [==============================] - 4s 9ms/step - loss: 18.0482 - val_loss: 15.5171
# Epoch 30/30
# 399/399 [==============================] - 4s 9ms/step - loss: 18.7141 - val_loss: 14.2302
# 45/45 [==============================] - 0s 4ms/step
# Epoch 1/30
# 400/400 [==============================] - 5s 10ms/step - loss: 18.1284 - val_loss: 17.0632
# Epoch 2/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.6557 - val_loss: 20.6078
# Epoch 3/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.3043 - val_loss: 18.6811
# Epoch 4/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.4290 - val_loss: 18.5526
# Epoch 5/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.2444 - val_loss: 19.8011
# Epoch 6/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.2614 - val_loss: 17.3131
# Epoch 7/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.1940 - val_loss: 18.3705
# Epoch 8/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.4518 - val_loss: 20.1597
# Epoch 9/30
# 400/400 [==============================] - 4s 9ms/step - loss: 16.9147 - val_loss: 16.8721
# Epoch 10/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.2334 - val_loss: 17.5632
# Epoch 11/30
# 400/400 [==============================] - 4s 9ms/step - loss: 16.9274 - val_loss: 17.0091
# Epoch 12/30
# 400/400 [==============================] - 4s 9ms/step - loss: 16.9985 - val_loss: 16.9070
# Epoch 13/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.1822 - val_loss: 18.1689
# Epoch 14/30
# 400/400 [==============================] - 4s 9ms/step - loss: 16.9863 - val_loss: 16.9777
# Epoch 15/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.1897 - val_loss: 16.8744
# Epoch 16/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.1202 - val_loss: 20.3680
# Epoch 17/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.1535 - val_loss: 17.3181
# Epoch 18/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.1748 - val_loss: 18.7764
# Epoch 19/30
# 400/400 [==============================] - 4s 9ms/step - loss: 16.9875 - val_loss: 17.4522
# Epoch 20/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.2722 - val_loss: 18.6263
# Epoch 21/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.3882 - val_loss: 17.0029
# Epoch 22/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.4883 - val_loss: 17.0448
# Epoch 23/30
# 400/400 [==============================] - 4s 9ms/step - loss: 16.9515 - val_loss: 17.0803
# Epoch 24/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.3001 - val_loss: 16.9678
# Epoch 25/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.4240 - val_loss: 16.9965
# Epoch 26/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.1940 - val_loss: 18.2189
# Epoch 27/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.2443 - val_loss: 21.6443
# Epoch 28/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.3658 - val_loss: 16.9872
# Epoch 29/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.0818 - val_loss: 16.9612
# Epoch 30/30
# 400/400 [==============================] - 4s 9ms/step - loss: 17.5609 - val_loss: 16.9774
# 44/44 [==============================] - 0s 4ms/step
# Epoch 1/30
# 399/399 [==============================] - 5s 10ms/step - loss: 26.2466 - val_loss: 23.0721
# Epoch 2/30
# 399/399 [==============================] - 4s 9ms/step - loss: 24.3032 - val_loss: 23.2908
# Epoch 3/30
# 399/399 [==============================] - 4s 9ms/step - loss: 24.2053 - val_loss: 29.7285
# Epoch 4/30
# 399/399 [==============================] - 4s 9ms/step - loss: 24.4205 - val_loss: 23.2234
# Epoch 5/30
# 399/399 [==============================] - 4s 9ms/step - loss: 24.1181 - val_loss: 22.9217
# Epoch 6/30
# 399/399 [==============================] - 4s 9ms/step - loss: 23.9580 - val_loss: 22.9650
# Epoch 7/30
# 399/399 [==============================] - 4s 9ms/step - loss: 23.8361 - val_loss: 22.8931
# Epoch 8/30
# 399/399 [==============================] - 4s 9ms/step - loss: 23.9227 - val_loss: 23.0716
# Epoch 9/30
# 399/399 [==============================] - 4s 9ms/step - loss: 23.8566 - val_loss: 23.0476
# Epoch 10/30
# 399/399 [==============================] - 4s 10ms/step - loss: 24.0991 - val_loss: 24.3094
# Epoch 11/30
# 399/399 [==============================] - 4s 9ms/step - loss: 23.8775 - val_loss: 22.8410
# Epoch 12/30
# 399/399 [==============================] - 4s 10ms/step - loss: 23.9658 - val_loss: 23.1475
# Epoch 13/30
# 399/399 [==============================] - 4s 9ms/step - loss: 23.6615 - val_loss: 27.0233
# Epoch 14/30
# 399/399 [==============================] - 4s 10ms/step - loss: 23.2627 - val_loss: 23.1552
# Epoch 15/30
# 399/399 [==============================] - 4s 9ms/step - loss: 24.0111 - val_loss: 23.1391
# Epoch 16/30
# 399/399 [==============================] - 4s 9ms/step - loss: 23.8091 - val_loss: 24.2313
# Epoch 17/30
# 399/399 [==============================] - 4s 10ms/step - loss: 23.9754 - val_loss: 23.0843
# Epoch 18/30
# 399/399 [==============================] - 4s 10ms/step - loss: 23.8363 - val_loss: 24.8940
# Epoch 19/30
# 399/399 [==============================] - 4s 9ms/step - loss: 23.5301 - val_loss: 22.6144
# Epoch 20/30
# 399/399 [==============================] - 4s 10ms/step - loss: 23.5152 - val_loss: 28.7671
# Epoch 21/30
# 399/399 [==============================] - 4s 10ms/step - loss: 24.4391 - val_loss: 22.7434
# Epoch 22/30
# 399/399 [==============================] - 4s 9ms/step - loss: 23.5801 - val_loss: 24.2568
# Epoch 23/30
# 399/399 [==============================] - 4s 9ms/step - loss: 23.4558 - val_loss: 22.5515
# Epoch 24/30
# 399/399 [==============================] - 4s 9ms/step - loss: 23.4430 - val_loss: 22.6708
# Epoch 25/30
# 399/399 [==============================] - 4s 9ms/step - loss: 23.4983 - val_loss: 28.2171
# Epoch 26/30
# 399/399 [==============================] - 4s 9ms/step - loss: 23.4605 - val_loss: 22.3135
# Epoch 27/30
# 399/399 [==============================] - 4s 9ms/step - loss: 23.1464 - val_loss: 22.7976
# Epoch 28/30
# 399/399 [==============================] - 4s 10ms/step - loss: 23.1903 - val_loss: 23.9868
# Epoch 29/30
# 399/399 [==============================] - 4s 9ms/step - loss: 22.9807 - val_loss: 21.9690
# Epoch 30/30
# 399/399 [==============================] - 4s 9ms/step - loss: 22.8127 - val_loss: 22.7303
# 45/45 [==============================] - 0s 4ms/step
# Epoch 1/30
# 400/400 [==============================] - 6s 11ms/step - loss: 18.3270 - val_loss: 20.4476
# Epoch 2/30
# 400/400 [==============================] - 4s 10ms/step - loss: 18.0908 - val_loss: 20.3553
# Epoch 3/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.1529 - val_loss: 20.3440
# Epoch 4/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.4917 - val_loss: 23.2009
# Epoch 5/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.5231 - val_loss: 21.9340
# Epoch 6/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.7504 - val_loss: 20.4835
# Epoch 7/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.1069 - val_loss: 20.9209
# Epoch 8/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.1551 - val_loss: 22.0615
# Epoch 9/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.0965 - val_loss: 20.4523
# Epoch 10/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.1642 - val_loss: 20.8065
# Epoch 11/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.8367 - val_loss: 21.1949
# Epoch 12/30
# 400/400 [==============================] - 4s 10ms/step - loss: 16.9481 - val_loss: 30.2533
# Epoch 13/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.4408 - val_loss: 20.4707
# Epoch 14/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.2085 - val_loss: 21.0359
# Epoch 15/30
# 400/400 [==============================] - 4s 10ms/step - loss: 18.0904 - val_loss: 20.3526
# Epoch 16/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.9473 - val_loss: 24.4247
# Epoch 17/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.2915 - val_loss: 21.6502
# Epoch 18/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.0592 - val_loss: 23.0909
# Epoch 19/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.8586 - val_loss: 21.3750
# Epoch 20/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.2580 - val_loss: 21.1275
# Epoch 21/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.1540 - val_loss: 20.9701
# Epoch 22/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.5073 - val_loss: 20.4811
# Epoch 23/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.8688 - val_loss: 29.4197
# Epoch 24/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.3343 - val_loss: 20.3501
# Epoch 25/30
# 400/400 [==============================] - 4s 10ms/step - loss: 16.8937 - val_loss: 22.9171
# Epoch 26/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.3332 - val_loss: 21.9017
# Epoch 27/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.1511 - val_loss: 21.0805
# Epoch 28/30
# 400/400 [==============================] - 4s 10ms/step - loss: 18.5377 - val_loss: 20.3787
# Epoch 29/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.1263 - val_loss: 22.1822
# Epoch 30/30
# 400/400 [==============================] - 4s 10ms/step - loss: 17.5165 - val_loss: 20.9369
# 44/44 [==============================] - 0s 4ms/step
# Epoch 1/30
# 401/401 [==============================] - 6s 11ms/step - loss: 18.7882 - val_loss: 11.1760
# Epoch 2/30
# 401/401 [==============================] - 4s 10ms/step - loss: 18.3267 - val_loss: 15.1419
# Epoch 3/30
# 401/401 [==============================] - 4s 10ms/step - loss: 17.9481 - val_loss: 28.0113
# Epoch 4/30
# 401/401 [==============================] - 4s 10ms/step - loss: 18.1609 - val_loss: 11.6360
# Epoch 5/30
# 401/401 [==============================] - 4s 10ms/step - loss: 18.3893 - val_loss: 11.7195
# Epoch 6/30
# 401/401 [==============================] - 4s 10ms/step - loss: 18.4151 - val_loss: 11.0192
# Epoch 7/30
# 401/401 [==============================] - 4s 10ms/step - loss: 17.9754 - val_loss: 10.6574
# Epoch 8/30
# 401/401 [==============================] - 4s 10ms/step - loss: 18.0240 - val_loss: 10.5703
# Epoch 9/30
# 401/401 [==============================] - 4s 10ms/step - loss: 17.5453 - val_loss: 13.1508
# Epoch 10/30
# 401/401 [==============================] - 4s 10ms/step - loss: 17.9517 - val_loss: 10.7378
# Epoch 11/30
# 401/401 [==============================] - 4s 10ms/step - loss: 17.8927 - val_loss: 11.7126
# Epoch 12/30
# 401/401 [==============================] - 4s 10ms/step - loss: 18.3688 - val_loss: 14.2549
# Epoch 13/30
# 401/401 [==============================] - 4s 10ms/step - loss: 17.6973 - val_loss: 10.5468
# Epoch 14/30
# 401/401 [==============================] - 4s 10ms/step - loss: 17.9443 - val_loss: 10.4226
# Epoch 15/30
# 401/401 [==============================] - 4s 10ms/step - loss: 18.3420 - val_loss: 10.7992
# Epoch 16/30
# 401/401 [==============================] - 4s 10ms/step - loss: 18.0276 - val_loss: 11.0772
# Epoch 17/30
# 401/401 [==============================] - 4s 10ms/step - loss: 18.5779 - val_loss: 18.0313
# Epoch 18/30
# 401/401 [==============================] - 4s 10ms/step - loss: 17.9486 - val_loss: 11.2493
# Epoch 19/30
# 401/401 [==============================] - 4s 10ms/step - loss: 18.0639 - val_loss: 10.9708
# Epoch 20/30
# 401/401 [==============================] - 4s 10ms/step - loss: 17.7261 - val_loss: 10.6418
# Epoch 21/30
# 401/401 [==============================] - 4s 10ms/step - loss: 18.2978 - val_loss: 10.5408
# Epoch 22/30
# 401/401 [==============================] - 4s 10ms/step - loss: 17.8634 - val_loss: 10.4711
# Epoch 23/30
# 401/401 [==============================] - 4s 10ms/step - loss: 18.3178 - val_loss: 11.7993
# Epoch 24/30
# 401/401 [==============================] - 4s 10ms/step - loss: 17.4573 - val_loss: 14.9491
# Epoch 25/30
# 401/401 [==============================] - 4s 10ms/step - loss: 18.3220 - val_loss: 20.3802
# Epoch 26/30
# 401/401 [==============================] - 4s 10ms/step - loss: 18.3257 - val_loss: 12.8747
# Epoch 27/30
# 401/401 [==============================] - 4s 10ms/step - loss: 17.7095 - val_loss: 11.2600
# Epoch 28/30
# 401/401 [==============================] - 4s 10ms/step - loss: 17.7427 - val_loss: 10.4155
# Epoch 29/30
# 401/401 [==============================] - 4s 10ms/step - loss: 17.6384 - val_loss: 10.4697
# Epoch 30/30
# 401/401 [==============================] - 4s 10ms/step - loss: 18.3366 - val_loss: 15.8777
# 44/44 [==============================] - 0s 4ms/step
# Epoch 1/30
# 398/398 [==============================] - 5s 11ms/step - loss: 19.2693 - val_loss: 17.1799
# Epoch 2/30
# 398/398 [==============================] - 4s 10ms/step - loss: 19.1181 - val_loss: 16.0956
# Epoch 3/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.7512 - val_loss: 29.9724
# Epoch 4/30
# 398/398 [==============================] - 4s 10ms/step - loss: 18.3378 - val_loss: 15.9722
# Epoch 5/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.7829 - val_loss: 15.8392
# Epoch 6/30
# 398/398 [==============================] - 4s 10ms/step - loss: 18.0145 - val_loss: 18.0390
# Epoch 7/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.7720 - val_loss: 15.8510
# Epoch 8/30
# 398/398 [==============================] - 4s 10ms/step - loss: 18.0587 - val_loss: 18.2724
# Epoch 9/30
# 398/398 [==============================] - 4s 10ms/step - loss: 18.4245 - val_loss: 16.2228
# Epoch 10/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.8261 - val_loss: 16.8510
# Epoch 11/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.8909 - val_loss: 19.4712
# Epoch 12/30
# 398/398 [==============================] - 4s 10ms/step - loss: 18.0259 - val_loss: 19.0627
# Epoch 13/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.8512 - val_loss: 15.8917
# Epoch 14/30
# 398/398 [==============================] - 4s 10ms/step - loss: 18.2044 - val_loss: 16.0090
# Epoch 15/30
# 398/398 [==============================] - 4s 10ms/step - loss: 18.0942 - val_loss: 20.5595
# Epoch 16/30
# 398/398 [==============================] - 4s 10ms/step - loss: 18.4466 - val_loss: 19.9332
# Epoch 17/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.7910 - val_loss: 15.8311
# Epoch 18/30
# 398/398 [==============================] - 4s 10ms/step - loss: 18.5589 - val_loss: 16.2482
# Epoch 19/30
# 398/398 [==============================] - 4s 10ms/step - loss: 18.8401 - val_loss: 15.9834
# Epoch 20/30
# 398/398 [==============================] - 4s 10ms/step - loss: 18.3077 - val_loss: 16.7433
# Epoch 21/30
# 398/398 [==============================] - 4s 10ms/step - loss: 18.2318 - val_loss: 17.0550
# Epoch 22/30
# 398/398 [==============================] - 4s 10ms/step - loss: 18.0032 - val_loss: 18.4309
# Epoch 23/30
# 398/398 [==============================] - 4s 10ms/step - loss: 18.6799 - val_loss: 16.0899
# Epoch 24/30
# 398/398 [==============================] - 4s 10ms/step - loss: 18.5533 - val_loss: 15.8428
# Epoch 25/30
# 398/398 [==============================] - 4s 10ms/step - loss: 18.0702 - val_loss: 15.9657
# Epoch 26/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.7330 - val_loss: 15.9513
# Epoch 27/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.6597 - val_loss: 16.5998
# Epoch 28/30
# 398/398 [==============================] - 4s 10ms/step - loss: 17.7755 - val_loss: 17.6147
# Epoch 29/30
# 398/398 [==============================] - 4s 9ms/step - loss: 18.3077 - val_loss: 16.6126
# Epoch 30/30
# 398/398 [==============================] - 4s 10ms/step - loss: 18.0209 - val_loss: 18.9597
# 47/47 [==============================] - 0s 4ms/step

# %%
print('rmse:',sqrt(mean_squared_error(dataset['Est_AC_POWER'],dataset['Pred_AC_POWER'])))
print('r2:',r2_score(dataset['Est_AC_POWER'],dataset['Pred_AC_POWER']))
# Out:
# rmse: 321.60607683744234
# r2: -0.1667807028168451

# %%
df_result = dataset.copy()
df_result['Real_Wh'] = list(df_result.Est_AC_POWER*df_result.TRIP_TIME/3600)
df_result['Pred_Wh'] = list(df_result.Pred_AC_POWER*df_result.TRIP_TIME/3600)
print(r2_score(df_result['Real_Wh'].tolist(),df_result['Pred_Wh'].tolist()))
print(pearson_corr_2(df_result['Real_Wh'].tolist(),df_result['Pred_Wh'].tolist()))
# Out:
# 0.2776047066903694
# 0.3309520223209053

# %%
high_model = df_result[df_result['DROP_TIME'] != 0]
low_model = df_result[df_result['DROP_TIME'] == 0]
rmse = sqrt(mean_squared_error(df_result['Real_Wh'], df_result['Pred_Wh']))

plt.figure(figsize=(8, 8),dpi=200)
x = np.arange(-1, 500, 1)
y1 = x
plt.plot(x, y1, color='orange')
plt.plot(x, y1+2*rmse, color='orange', linestyle=':')
plt.plot(x, y1-2*rmse, color='orange', linestyle=':')

plt.scatter(low_model['Real_Wh'],low_model['Pred_Wh'],s=10,label='低出力モード')
plt.scatter(high_model['Real_Wh'],high_model['Pred_Wh'],s=10,c='r',alpha=0.5,label='高出力モード')

plt.xlabel('測定値 [kWh]',fontsize=20)
plt.ylabel('推定値 [kWh]',fontsize=20)
plt.legend(loc='upper left',fontsize=16)
plt.tick_params(labelsize=12)

plt.show()

# %%
plt.figure(figsize=(4, 4),dpi=200)
sns.histplot(df_result['Real_Wh'], kde=True, bins=50)
plt.xlabel('実測値 [kWh]',fontsize=12)
plt.ylabel('count',fontsize=12)
plt.ylim(0,8000)
plt.show()

# %%
plt.figure(figsize=(4, 4),dpi=200)
sns.histplot(df_result['Pred_Wh'], kde=True, bins=50)
plt.xlabel('推定値 [kWh]',fontsize=12)
plt.ylabel('count',fontsize=12)
plt.ylim(0,8000)
plt.show()

# %%
print('実測値平均:',df_result['Real_Wh'].mean(),'実測値分散:',df_result['Real_Wh'].var())
print('推定値平均:',df_result['Pred_Wh'].mean(),'推定値分散:',df_result['Pred_Wh'].var())
# Out:
# 実測値平均: 15.957200083400766 実測値分散: 667.6596219452024
# 推定値平均: 10.85682734267388 推定値分散: 138.44088937225447

# %%
print('実測値αβ:',calculate_alpha_beta(df_result['Real_Wh'].mean(),df_result['Real_Wh'].var()))
print('推定値αβ:',calculate_alpha_beta(df_result['Pred_Wh'].mean(),df_result['Pred_Wh'].var()))
# Out:
# 実測値αβ: (41.8406498919397, 0.3813803113625825)
# 推定値αβ: (12.751505113109635, 0.8514153620588785)
